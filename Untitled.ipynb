# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
import os
import shutil
import random

# Path dataset asal
dataset_path = "Batik/"

# Path tujuan
train_path = "Batik/train/"
val_path = "Batik/validation/"

# Persentase split
split_ratio = 0.8  # 80% training, 20% validation

# Buat folder tujuan jika belum ada
os.makedirs(train_path, exist_ok=True)
os.makedirs(val_path, exist_ok=True)

# Loop setiap kelas (folder dalam dataset_raw/)
for class_name in os.listdir(dataset_path):
    class_folder = os.path.join(dataset_path, class_name)

    if os.path.isdir(class_folder):  # Pastikan hanya folder
        images = [f for f in os.listdir(class_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]  # Ambil hanya gambar
        random.shuffle(images)  # Acak urutan gambar

        train_size = int(len(images) * split_ratio)
        train_images = images[:train_size]
        val_images = images[train_size:]

        # Buat subfolder per kelas dalam train dan validation
        os.makedirs(os.path.join(train_path, class_name), exist_ok=True)
        os.makedirs(os.path.join(val_path, class_name), exist_ok=True)

        # Salin gambar ke train/
        for img in train_images:
            src = os.path.join(class_folder, img)
            dst = os.path.join(train_path, class_name, img)
            shutil.copy2(src, dst)  # Gunakan copy2 agar metadata file ikut terbawa

        # Salin gambar ke validation/
        for img in val_images:
            src = os.path.join(class_folder, img)
            dst = os.path.join(val_path, class_name, img)
            shutil.copy2(src, dst)

print("✅ Dataset berhasil dibagi menjadi train & validation tanpa menghapus data asli!")
# Out:
# ✅ Dataset berhasil dibagi menjadi train & validation tanpa menghapus data asli!

# %%
# Path dataset
train_dir = "Batik/train"
val_dir = "Batik/validation"

# Preprocessing data (augmentasi & normalisasi)
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Simpan daftar kelas
class_names = list(train_generator.class_indices.keys())
print(f"Kelas yang dikenali: {class_names}")
# Out:
# Found 40 images belonging to 6 classes.
# Found 29 images belonging to 6 classes.
# Kelas yang dikenali: ['Bangkalan', 'Pamekasan', 'Sampang', 'Sumenep', 'train', 'validation']

# %%
# Load MobileNetV2 tanpa top layer
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# Tambahkan layer baru
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)
x = Dense(len(class_names), activation="softmax")(x)

# Buat model baru
model = Model(inputs=base_model.input, outputs=x)

# Freeze layer awal
for layer in base_model.layers:
    layer.trainable = False

# Compile model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10
)
# Out:
# D:\Anaconda\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.0167 - loss: 2.3427 - val_accuracy: 0.0690 - val_loss: 2.1027
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step - accuracy: 0.0500 - loss: 2.1940 - val_accuracy: 0.2414 - val_loss: 1.8515
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - accuracy: 0.2167 - loss: 1.8702 - val_accuracy: 0.4138 - val_loss: 1.6527
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 759ms/step - accuracy: 0.3750 - loss: 1.7140 - val_accuracy: 0.5517 - val_loss: 1.4954
# Epoch 5/10
# ...

# %%
model.save("batik_model.h5")
print("✅ Model telah disimpan!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model telah disimpan!

# %%
# Load model yang telah disimpan
model = tf.keras.models.load_model("batik_model.h5")

# Cek daftar kelas
print(f"Kelas yang dikenali: {class_names}")

def predict_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction)

    print(f"🔍 Prediksi: {class_names[predicted_class]} (Confidence: {confidence:.2f})")

    # Tampilkan gambar
    plt.imshow(img)
    plt.title(f"Prediksi: {class_names[predicted_class]} ({confidence:.2f})")
    plt.axis("off")
    plt.show()

# Uji prediksi pada gambar baru
predict_image("coba.jpg")  # Ganti dengan path gambar uji
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Kelas yang dikenali: ['Bangkalan', 'Pamekasan', 'Sampang', 'Sumenep', 'train', 'validation']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 🔍 Prediksi: Sampang (Confidence: 0.63)

# %%
import tensorflow as tf

# Load model yang sudah dilatih
model = tf.keras.models.load_model("batik_model.h5")

# Buat converter untuk TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Opsi optimasi (jika ingin model lebih kecil dan cepat)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Optimasi untuk ukuran lebih kecil
# converter.target_spec.supported_types = [tf.float16]  # Opsional: gunakan float16 untuk menghemat memori

# Konversi ke format TFLite
tflite_model = converter.convert()

# Simpan model TFLite ke file
with open("mobilenetv2_batik.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Model berhasil dikonversi ke TFLite: mobilenetv2_batik.tflite")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\lenovo\AppData\Local\Temp\tmp2wjhah5y\assets
# INFO:tensorflow:Assets written to: C:\Users\lenovo\AppData\Local\Temp\tmp2wjhah5y\assets
# Saved artifact at 'C:\Users\lenovo\AppData\Local\Temp\tmp2wjhah5y'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   2175643739232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2175643750816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2175643751872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2175643739760: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
import numpy as np
import tensorflow.lite as tflite
from tensorflow.keras.preprocessing import image

# Load model TFLite
interpreter = tflite.Interpreter(model_path="mobilenetv2_batik.tflite")
interpreter.allocate_tensors()

# Dapatkan informasi input dan output
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Daftar nama kelas sesuai urutan saat training
class_names = ["Bangkalan", "Pamekasan", "Sampang", "Sumenep"]  # Ganti sesuai dataset

# Fungsi untuk melakukan prediksi
def predict_tflite(img_path):
    # Preprocess gambar
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0).astype(np.float32)  # Sesuaikan dengan input model

    # Masukkan gambar ke model
    interpreter.set_tensor(input_details[0]['index'], img_array)
    interpreter.invoke()

    # Ambil hasil prediksi
    output_data = interpreter.get_tensor(output_details[0]['index'])
    predicted_class = np.argmax(output_data)
    confidence = output_data[0][predicted_class]  # Ambil tingkat keyakinan prediksi

    print(f"Prediksi TFLite: {class_names[predicted_class]} (Confidence: {confidence:.2f})")

# Uji dengan gambar contoh
predict_tflite("coba.jpg")  # Ganti dengan path gambar batik
# Out:
# Prediksi TFLite: Sampang (Confidence: 0.58)

# %%
import uvicorn
import numpy as np
import tensorflow.lite as tflite
from fastapi import FastAPI, File, UploadFile
from fastapi.staticfiles import StaticFiles
from tensorflow.keras.preprocessing import image
from PIL import Image
import io
import os
import uuid
from fastapi.responses import FileResponse

app = FastAPI()

# Load model TFLite
interpreter = tflite.Interpreter(model_path="mobilenetv2_batik.tflite")
interpreter.allocate_tensors()

# Ambil input dan output model
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Nama-nama kelas batik
class_names = ["Bangkalan", "Pamekasan", "Sampang", "Sumenep"] 

# Buat folder untuk menyimpan gambar jika belum ada
UPLOAD_FOLDER = "uploaded_images"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

# Fungsi prediksi gambar
def predict_image(img):
    img = img.resize((224, 224))  
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0).astype(np.float32)

    # Masukkan ke model
    interpreter.set_tensor(input_details[0]['index'], img_array)
    interpreter.invoke()

    # Ambil hasil prediksi
    output_data = interpreter.get_tensor(output_details[0]['index'])
    predicted_class = np.argmax(output_data)
    
    return class_names[predicted_class], float(np.max(output_data))

@app.post("/predict/")
async def predict(file: UploadFile = File(...)):
    img_bytes = await file.read()
    img = Image.open(io.BytesIO(img_bytes)).convert("RGB")

    # Gunakan UUID untuk nama unik, tetapi tetap simpan ekstensi asli
    file_extension = file.filename.split(".")[-1]
    unique_filename = f"{uuid.uuid4()}.{file_extension}"
    file_path = os.path.join(UPLOAD_FOLDER, unique_filename)

    # Simpan gambar ke folder
    img.save(file_path)

    label, confidence = predict_image(img)

    # Buat URL untuk mengakses gambar
    image_url = f"http://localhost:8000/images/{unique_filename}"

    return {
        "class": label,
        "confidence": confidence,
        "image_url": image_url
    }

# Endpoint untuk mengakses gambar
@app.get("/images/{filename}")
async def get_image(filename: str):
    file_path = os.path.join(UPLOAD_FOLDER, filename)
    return FileResponse(file_path)

# Sajikan folder gambar sebagai static files
app.mount("/images", StaticFiles(directory=UPLOAD_FOLDER), name="images")

if __name__ == "__main__":
    uvicorn.run("server:app", host="0.0.0.0", port=int(os.getenv("PORT", 8000)), reload=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12008\1221731626.py in <module>
#       2 import numpy as np
#       3 import tensorflow.lite as tflite
# ----> 4 from fastapi import FastAPI, File, UploadFile
#       5 from fastapi.staticfiles import StaticFiles
#       6 from tensorflow.keras.preprocessing import image
#
# ModuleNotFoundError: No module named 'fastapi'
